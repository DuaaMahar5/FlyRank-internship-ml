# %% [markdown]
# <a href="https://colab.research.google.com/github/DuaaMahar5/FlyRank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DuaaMahar5/FlyRank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Refresh/ Content Opportunity Scoring
#
# I chose this lane because it's a supervised classification problem with a clear,interpretable answer, it addresses a need for the content team: to prioritize their efforts on a large inventory of pages.
#
# Aim is to develop a scoring system using the content refresh dataset to identify pages with high potential or risk, measured by changes in engagement and search ranking. A wrong recommendation is costly, leading to wasted effort or missed performance improvements. ML can help because the patterns are too complex for simple rules,though i will test this as i go. Our output will serve as a decision-support tool.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Question:
# Which pages should be reviewed first for refresh,expansion,protection,pruning, or monitoring?
#
# Decision improved:
# helping the content team prioritize, and  which action to take on each like refresh,expand,protect,prune,or just keep monitoring.
#
# Who acts on it:
# the content team, who otherwise has to review the full page inventory by hand with no prioritization.
#
# Cost of a wrong recommendation:
# if a page is flagged but did not need attention, that is wasted time.If a page needed attention but was not flagged, it keeps losing traffic without anyone noticing.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# loading the starter dataset shows 30,000 total content items, with an average performance trend of -4.8% meaning , on average ,content is slightly declining rather than improving.Of those, 19,715 items (about 66%) show a negative trend, suggesting a large share of the catalog could be refresh candidates worth reviewing.

# %%
# Clone the repository to get the data files
import os

repo_url = "https://github.com/DuaaMahar5/FlyRank-internship-ml.git"
repo_name = "FlyRank-internship-ml"

# Check if the repository is already cloned
if not os.path.exists(repo_name):
    print(f"Cloning {repo_url}...")
    # !git clone {repo_url}
    print("Repository cloned successfully.")
else:
    print(f"Repository '{repo_name}' already exists. Skipping clone.")

# Change to the repository directory to ensure correct pathing for data loading
# if the data loading cell expects the current working directory to be the repo root.
# However, the current data loading code uses 'data/raw/', so it should work relative to the Colab root
# as long as the repo is cloned in the root. Let's verify current directory and content.

print(f"Current working directory: {os.getcwd()}")
# List contents of the cloned repo to confirm data directory structure
if os.path.exists(repo_name):
    print(f"Contents of '{repo_name}' directory:")
    # !ls -F {repo_name}
    if os.path.exists(f"{repo_name}/data/raw"):
        print(f"Contents of '{repo_name}/data/raw' directory:")
        # !ls -F {repo_name}/data/raw
    else:
        print(f"'{repo_name}/data/raw' directory not found. Please check repository structure.")
else:
    print(f"Repository '{repo_name}' not found after cloning attempt. Please check git clone output.")

# After cloning, the data will be in './FlyRank-internship-ml/data/raw/'.
# The data loading cell '19Acb8jQfeMW' currently looks for 'data/raw/'.
# We need to adjust the path in the data loading cell to reference the cloned repository.
# I will modify the next cell to use the correct path after this cell is executed.
# Out:
# Cloning https://github.com/DuaaMahar5/FlyRank-internship-ml.git...
# Cloning into 'FlyRank-internship-ml'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 119 (delta 35), reused 94 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.84 MiB | 4.86 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# Repository cloned successfully.
# Current working directory: /content
# Contents of 'FlyRank-internship-ml' directory:
# AGENTS.md  DATA_USE.md	LICENSE     README.md	      SETUP.md	   work/
# CLAUDE.md  docs/	notebooks/  requirements.txt  skills/
# data/	   GUIDE.md	outputs/    scripts/	      submission/
# Contents of 'FlyRank-internship-ml/data/raw' directory:
# content_refresh_anonymized.csv

# %%
import pandas as pd

# Assuming the file is now located in the cloned repository
file_path = './FlyRank-internship-ml/data/raw/content_refresh_anonymized.csv'

try:
    df = pd.read_csv(file_path)
    print("Dataset loaded successfully.")
    print(f"Shape of the DataFrame: {df.shape}")
    display(df.head())

    # --- Numbers for Section 3 ---
    print("\n--- Key Data Insights for Section 3 ---")

    # 1. Total number of content items
    total_content_items = df.shape[0]
    print(f"Total content items in the dataset: {total_content_items:,}")

    # 2. Average trend percentage (assuming 'trend_pct' is a numerical column)
    # It's good practice to handle potential missing values or non-numeric types
    avg_trend_pct = df['trend_pct'].mean()
    print(f"Average performance trend (trend_pct): {avg_trend_pct:.1f}%")

    # 3. Number of content items with a negative trend
    negative_trend_items = df[df['trend_pct'] < 0].shape[0]
    print(f"Number of content items with a negative trend: {negative_trend_items:,}")

except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found.")
    print("Please ensure the repository is cloned and the file exists at this path.")
except Exception as e:
    print(f"An error occurred while loading the dataset: {e}")
# Out:
# Dataset loaded successfully.
# Shape of the DataFrame: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# My work can say what's observed in this real dataset(e.g. "these pages have low CTR and declining position"), and at most suggest a direction("this page looks like a candidate for review"). It's meant aa decision-support something to help a person decide, not decide for them.
#
# Even though the data is real, it only shows the outcome of Google's ranking not the actual algorithm behind it.So my work can never claim a refresh caused a page to recover(no experiment was run), and it can't predict or explain how Google's real ranking algorithm works.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
